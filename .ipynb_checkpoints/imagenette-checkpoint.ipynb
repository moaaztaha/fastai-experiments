# %%
from fastai.vision.all import *

# %%
path = untar_data(URLs.IMAGENETTE_160)

# %%
path.ls()
# Out:
# (#2) [Path('/storage/data/imagenette2-160/val'),Path('/storage/data/imagenette2-160/train')]

# %%
lbl_dict = dict(
    n01440764='tench',
    n02102040='English springer',
    n02979186='cassette player',
    n03000684='chain saw',
    n03028079='church',
    n03394916='French horn',
    n03417042='garbage truck',
    n03425413='gas pump',
    n03445777='golf ball',
    n03888257='parachute'
)

# %%
imagenette = DataBlock(blocks = (ImageBlock, CategoryBlock),
                      get_items= get_image_files,
                      get_y = Pipeline([parent_label, lbl_dict.__getitem__]),
                      splitter = GrandparentSplitter(valid_name='val'),
                      item_tfms=RandomResizedCrop(128, min_scale=0.35),
                      batch_tfms=Normalize.from_stats(*imagenet_stats))
dls = imagenette.dataloaders(path)

# %%
dls.show_batch()

# %%
learn = cnn_learner(dls, resnet34, pretrained=False, metrics=accuracy)

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.002290867641568184, lr_steep=1.0964781722577754e-06)

# %%
learn.fit_one_cycle(6, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.420186</td>
#       <td>2.080745</td>
#       <td>0.355924</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.164318</td>
#       <td>2.624781</td>
#       <td>0.282548</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.824661</td>
#       <td>1.598185</td>
#       <td>0.469809</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.780772</td>
#       <td>1.648682</td>
#       <td>0.448153</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.436589</td>
#       <td>1.238472</td>
#       <td>0.589299</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.unfreeze()
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=1.2022644114040304e-06, lr_steep=7.585775847473997e-07)

# %%
learn.fit_one_cycle(6, slice(7e-6, 7e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.129125</td>
#       <td>1.030938</td>
#       <td>0.667006</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.113302</td>
#       <td>1.004871</td>
#       <td>0.667006</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.071032</td>
#       <td>0.965425</td>
#       <td>0.684586</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.041481</td>
#       <td>0.953748</td>
#       <td>0.684586</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.032820</td>
#       <td>0.931287</td>
#       <td>0.697834</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
imagenette = DataBlock(blocks = (ImageBlock, CategoryBlock),
                      get_items= get_image_files,
                      get_y = Pipeline([parent_label, lbl_dict.__getitem__]),
                      splitter = GrandparentSplitter(valid_name='val'),
                      item_tfms=Resize(128),
                      batch_tfms=Normalize.from_stats(*imagenet_stats))
dls = imagenette.dataloaders(path)

# %%
learn = cnn_learner(dls, resnet34, pretrained=False, metrics=accuracy)

# %%
learn.fit_one_cycle(6, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.404901</td>
#       <td>3.001209</td>
#       <td>0.311083</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.926988</td>
#       <td>3.134289</td>
#       <td>0.358217</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.708575</td>
#       <td>1.599445</td>
#       <td>0.495287</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.651603</td>
#       <td>1.531592</td>
#       <td>0.517197</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.217646</td>
#       <td>1.085503</td>
#       <td>0.657834</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.unfreeze()
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=3.981071640737355e-05, lr_steep=1.3182567499825382e-06)

# %%
learn.fit_one_cycle(6, slice(3e-6, 3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.909766</td>
#       <td>0.920286</td>
#       <td>0.714650</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.886942</td>
#       <td>0.911743</td>
#       <td>0.722548</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.856332</td>
#       <td>0.875601</td>
#       <td>0.727643</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.836373</td>
#       <td>0.907836</td>
#       <td>0.730446</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.807928</td>
#       <td>0.863653</td>
#       <td>0.729936</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn = cnn_learner(dls, resnet34, pretrained=False, metrics=accuracy)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.924893</td>
#       <td>0.972935</td>
#       <td>0.715669</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.908293</td>
#       <td>0.974610</td>
#       <td>0.716943</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.919518</td>
#       <td>0.994780</td>
#       <td>0.714650</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.926615</td>
#       <td>0.949346</td>
#       <td>0.720510</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.924905</td>
#       <td>0.928606</td>
#       <td>0.721783</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn = cnn_learner(dls, resnet34, pretrained=False, metrics=accuracy)
learn.fit_one_cycle(12, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.553326</td>
#       <td>2.265606</td>
#       <td>0.377580</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.007430</td>
#       <td>5.874595</td>
#       <td>0.183439</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.647306</td>
#       <td>1.621627</td>
#       <td>0.482293</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.870374</td>
#       <td>4.714480</td>
#       <td>0.365350</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.879335</td>
#       <td>2.313685</td>
#       <td>0.337580</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
imagenette = DataBlock(blocks = (ImageBlock, CategoryBlock),
                      get_items= get_image_files,
                      get_y = Pipeline([parent_label, lbl_dict.__getitem__]),
                      splitter = GrandparentSplitter(valid_name='val'),
                      item_tfms=Resize(160),
                      batch_tfms=aug_transforms(size=124, xtra_tfms=Normalize.from_stats(*imagenet_stats)))
dls = imagenette.dataloaders(path)

# %%
learn = cnn_learner(dls, resnet34, pretrained=False, metrics=accuracy)
learn.fit_one_cycle(12, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.572009</td>
#       <td>2.415609</td>
#       <td>0.334268</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.066936</td>
#       <td>1.891704</td>
#       <td>0.396178</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.228839</td>
#       <td>2.083877</td>
#       <td>0.304968</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.882538</td>
#       <td>1.638336</td>
#       <td>0.442548</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.671957</td>
#       <td>1.500471</td>
#       <td>0.516688</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
imagenette = DataBlock(blocks = (ImageBlock, CategoryBlock),
                      get_items= get_image_files,
                      get_y = Pipeline([parent_label, lbl_dict.__getitem__]),
                      splitter = GrandparentSplitter(valid_name='val'),
                      item_tfms=[Resize(160), FlipItem()],
                      batch_tfms=aug_transforms(size=124, xtra_tfms=Normalize.from_stats(*imagenet_stats)))
dls = imagenette.dataloaders(path)

# %%
learn = cnn_learner(dls, resnet34, pretrained=False, metrics=accuracy)
learn.fit_one_cycle(12, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.621584</td>
#       <td>2.216316</td>
#       <td>0.350573</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.064467</td>
#       <td>2.776552</td>
#       <td>0.356433</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.837413</td>
#       <td>1.998073</td>
#       <td>0.347006</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.634079</td>
#       <td>1.784301</td>
#       <td>0.505223</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.634609</td>
#       <td>1.586542</td>
#       <td>0.481529</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
imagenette = DataBlock(blocks = (ImageBlock, CategoryBlock),
                      get_items= get_image_files,
                      get_y = Pipeline([parent_label, lbl_dict.__getitem__]),
                      splitter = GrandparentSplitter(valid_name='val'),
                      item_tfms=Resize(160),
                      batch_tfms=aug_transforms(size=124, max_zoom=1.25, xtra_tfms=Normalize.from_stats(*imagenet_stats)))
dls = imagenette.dataloaders(path)
learn = cnn_learner(dls, resnet34, pretrained=False, metrics=accuracy)
learn.fit_one_cycle(12, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.530186</td>
#       <td>1.923012</td>
#       <td>0.369172</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.012067</td>
#       <td>2.538587</td>
#       <td>0.452994</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.895513</td>
#       <td>1.590497</td>
#       <td>0.470318</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.968981</td>
#       <td>1.868599</td>
#       <td>0.378344</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.564817</td>
#       <td>1.435324</td>
#       <td>0.528153</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
imagenette = DataBlock(blocks = (ImageBlock, CategoryBlock),
                      get_items= get_image_files,
                      get_y = Pipeline([parent_label, lbl_dict.__getitem__]),
                      splitter = GrandparentSplitter(valid_name='val'),
                      item_tfms=Resize(160),
                      batch_tfms=aug_transforms(size=124, xtra_tfms=Normalize.from_stats(*imagenet_stats)))
dls = imagenette.dataloaders(path)

# %%
dls.vocab
# Out:
# (#10) ['English springer','French horn','cassette player','chain saw','church','garbage truck','gas pump','golf ball','parachute','tench']

# %%
learn = Learner(dls, xresnet34(n_out=10), loss_func=CrossEntropyLossFlat(), metrics=accuracy)
learn.fit_one_cycle(12, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.546154</td>
#       <td>1.328273</td>
#       <td>0.565605</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.244242</td>
#       <td>1.558786</td>
#       <td>0.516688</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.041605</td>
#       <td>1.340584</td>
#       <td>0.583185</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.879873</td>
#       <td>0.845327</td>
#       <td>0.727898</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.758350</td>
#       <td>0.849270</td>
#       <td>0.731210</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn = Learner(dls, xresnet34(n_out=10), loss_func=CrossEntropyLossFlat(), metrics=accuracy)
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.001096478197723627, lr_steep=0.0006918309954926372)

# %%
learn.fit_one_cycle(6, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.523936</td>
#       <td>1.602779</td>
#       <td>0.484586</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.169266</td>
#       <td>1.220995</td>
#       <td>0.619618</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.950507</td>
#       <td>0.954333</td>
#       <td>0.689682</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.758349</td>
#       <td>0.788178</td>
#       <td>0.754140</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.622829</td>
#       <td>0.591308</td>
#       <td>0.810701</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=1.0964782268274575e-05, lr_steep=1.5848931980144698e-06)

# %%
learn.fit_one_cycle(6, slice(5e-5, 5e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.702894</td>
#       <td>1.045350</td>
#       <td>0.673885</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.804726</td>
#       <td>1.159571</td>
#       <td>0.654777</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.718791</td>
#       <td>0.734664</td>
#       <td>0.762038</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.569487</td>
#       <td>0.663210</td>
#       <td>0.792611</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.433634</td>
#       <td>0.453512</td>
#       <td>0.854013</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn = Learner(dls, xresnet34(n_out=10), loss_func=CrossEntropyLossFlat(), metrics=accuracy)
learn.fit_one_cycle(6, slice(3e-5, 3e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.532651</td>
#       <td>2.198998</td>
#       <td>0.401019</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.202061</td>
#       <td>1.011673</td>
#       <td>0.668280</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.976395</td>
#       <td>1.131579</td>
#       <td>0.640510</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.778567</td>
#       <td>0.800224</td>
#       <td>0.738089</td>
#       <td>00:21</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.617208</td>
#       <td>0.568467</td>
#       <td>0.817834</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn = Learner(dls, xresnet50(n_out=10), loss_func=CrossEntropyLossFlat(), metrics=accuracy)
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=0.0003019951749593019, lr_steep=0.0003311311302240938)

# %%
learn.fit_one_cycle(6, 3e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.637406</td>
#       <td>3.133936</td>
#       <td>0.381401</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.342978</td>
#       <td>1.447746</td>
#       <td>0.580637</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.056465</td>
#       <td>1.339085</td>
#       <td>0.596943</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.839233</td>
#       <td>0.756980</td>
#       <td>0.750828</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.691295</td>
#       <td>0.644891</td>
#       <td>0.792611</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.lr_find()
# Out:
# SuggestedLRs(lr_min=6.309573450380412e-08, lr_steep=8.31763736641733e-06)

# %%
learn.fit_one_cycle(6, slice(3e-5, 3e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.722179</td>
#       <td>1.445496</td>
#       <td>0.601274</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.820641</td>
#       <td>0.899680</td>
#       <td>0.709299</td>
#       <td>00:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.685173</td>
#       <td>0.721469</td>
#       <td>0.779873</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.597465</td>
#       <td>0.599897</td>
#       <td>0.809172</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.469794</td>
#       <td>0.485469</td>
#       <td>0.847389</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn = Learner(dls, xresnet50(n_out=10), loss_func=CrossEntropyLossFlat(), metrics=accuracy)
learn.fine_tune(6)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.618629</td>
#       <td>2.336766</td>
#       <td>0.402548</td>
#       <td>00:35</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.100274</td>
#       <td>1.352257</td>
#       <td>0.570446</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.066805</td>
#       <td>1.098700</td>
#       <td>0.641019</td>
#       <td>00:35</td>
#     </tr>
#     <tr>
#       <td>2</td>
# ...
